# %%
#importing all the required packags pandas and numpy
import pandas as pd
import numpy as np

# %%
#Read csv file from notebook local folder location
#referred as population dataframe
df = pd.read_csv(r'data-text.csv',header=0)
#print top 2 records from dataframe
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#Read berlin weather csv file from notebook local folder location
#referred as berlin weather dataframe
df1 = pd.read_csv('berlin_weather_oldest.csv',header=0)
#print top 5 records from dataframe
df1.head(5)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %% [markdown]
# # 1. Get the Metadata from the above files.

# %%
#metadata for population dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 327.4+ KB

# %%
#metadata for berlin weather dataframe
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# # 2. Get the row names from the above files.

# %%
#Get the row names for population dataframe (first dataframe)
df.index.values 
#list(df.index)
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
# Get the row names for berlin weather dataframe (first dataframe)
df1.index.values 

#(df1.axes[0].tolist)
#list(df1.index)
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# # 3. Change the column name from any of the above file.

# %%
#Rename the Indicator column name to Indicator-Id for population dataframe i.e first dataframe and print top 3 rows
df.rename(columns={'Indicator': 'Indicator-Id'}).head(3)
# Out:
#                         Indicator-Id PUBLISH STATES  Year WHO region  \
# 0   Life expectancy at birth (years)      Published  1990     Europe
# 1   Life expectancy at birth (years)      Published  2000     Europe
# 2  Life expectancy at age 60 (years)      Published  2012     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
# 2             High-income  Andorra      Female             28     28.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN

# %%
#observe the column name permanently not changed to Indicator-Id with the above opration on population dataframe
df.head(2)
# Out:
#                        Indicator-Id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# # 4. Change the column name from any of the above file and store the changes made permanently.

# %%
# this operation using inplace=True will permanently make the column name change from Indicator to Indicator-Id in population dataframe
df.rename(columns={'Indicator': 'Indicator-Id'},inplace=True)

# %%
#observe that column name Indictor permanently changed to Indicator-Id
df.head(2)
# Out:
#                        Indicator-Id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# # 5. Change the names of multiple columns.

# %%
#Renaming the column names Indicator-Id to Indicator-Id1 and Year to Birth Year for population dataframe and using inplace=True for permanent changes
df.rename(columns={'Indicator-Id': 'Indicator-Id1','Year':'Birth Year'},inplace=True)
df.head(2)
# Out:
#                       Indicator-Id1 PUBLISH STATES  Birth Year WHO region  \
# 0  Life expectancy at birth (years)      Published        1990     Europe
# 1  Life expectancy at birth (years)      Published        2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# # 6.Arrange values of a particular column in ascending order.

# %%
#sorting the population dataframe by Birth Year in ascending order
df.sort_values(by='Birth Year',ascending=True)
# Out:
#                                         Indicator-Id1 PUBLISH STATES  \
# 0                    Life expectancy at birth (years)      Published
# 1270                 Life expectancy at birth (years)      Published
# 3193                 Life expectancy at birth (years)      Published
# 3194                 Life expectancy at birth (years)      Published
# 3197                Life expectancy at age 60 (years)      Published
# 1264                 Life expectancy at birth (years)      Published
# 3199                Life expectancy at age 60 (years)      Published
# 1262                Life expectancy at age 60 (years)      Published
# 1259                 Life expectancy at birth (years)      Published
# 3203                Life expectancy at age 60 (years)      Published
# 1273                Life expectancy at age 60 (years)      Published
# 3204                 Life expectancy at birth (years)      Published
# 1253                 Life expectancy at birth (years)      Published
# ...

# %% [markdown]
# # 7. Arrange multiple column values in ascending order.

# %%
#sorting population dataframe by Birth Year and Diplay Value columns both in ascending order
df.sort_values(['Birth Year','Display Value'],ascending=[1,1])
# Out:
#                           Indicator-Id1 PUBLISH STATES  Birth Year  \
# 1474  Life expectancy at age 60 (years)      Published        1990
# 1476  Life expectancy at age 60 (years)      Published        1990
# 1813  Life expectancy at age 60 (years)      Published        1990
# 3071  Life expectancy at age 60 (years)      Published        1990
# 577   Life expectancy at age 60 (years)      Published        1990
# 3203  Life expectancy at age 60 (years)      Published        1990
# 4275  Life expectancy at age 60 (years)      Published        1990
# 604   Life expectancy at age 60 (years)      Published        1990
# 686   Life expectancy at age 60 (years)      Published        1990
# 991   Life expectancy at age 60 (years)      Published        1990
# 1181  Life expectancy at age 60 (years)      Published        1990
# 1631  Life expectancy at age 60 (years)      Published        1990
# 1899  Life expectancy at age 60 (years)      Published        1990
# ...

# %% [markdown]
# # 8. Make country as the first column of the dataframe.

# %%
#get the unique values out of country and all the column values, that will remove second time country field in its original locaiton
#now get the population dataframe using head for fetching first 5 rows 
#class given solution
df[pd.unique(['Country']+df.columns.values.tolist()).tolist()].head()
# Out:
#                 Country                      Indicator-Id1 PUBLISH STATES  \
# 0               Andorra   Life expectancy at birth (years)      Published
# 1               Andorra   Life expectancy at birth (years)      Published
# 2               Andorra  Life expectancy at age 60 (years)      Published
# 3               Andorra  Life expectancy at age 60 (years)      Published
# 4  United Arab Emirates   Life expectancy at birth (years)      Published
#
#    Birth Year             WHO region World Bank income group         Sex  \
# 0        1990                 Europe             High-income  Both sexes
# 1        2000                 Europe             High-income  Both sexes
# 2        2012                 Europe             High-income      Female
# 3        2000                 Europe             High-income  Both sexes
# 4        2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# ...

# %%
#alternative option of rearrning Country column as the first column. 
df.reindex(['Country','Indicator-Id1','PUBLISH STATES','Birth Year','WHO region','World Bank income group','Sex','Display Value','Numeric','Low','High','Comments'], axis=1)
df.head()
# Out:
#                 Country                      Indicator-Id1 PUBLISH STATES  \
# 0               Andorra   Life expectancy at birth (years)      Published
# 1               Andorra   Life expectancy at birth (years)      Published
# 2               Andorra  Life expectancy at age 60 (years)      Published
# 3               Andorra  Life expectancy at age 60 (years)      Published
# 4  United Arab Emirates   Life expectancy at birth (years)      Published
#
#    Birth Year             WHO region World Bank income group         Sex  \
# 0        1990                 Europe             High-income  Both sexes
# 1        2000                 Europe             High-income  Both sexes
# 2        2012                 Europe             High-income      Female
# 3        2000                 Europe             High-income  Both sexes
# 4        2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# ...

# %% [markdown]
# # 9. Get the column array using a variable

# %%
#printing all the Country column values in an an array from population dataframe
countryNames = df.Country.values
print(countryNames)
# Out:
# ['Andorra' 'Andorra' 'Andorra' 'Andorra' 'United Arab Emirates']

# %% [markdown]
# # 10. Get the subset rows 11, 24, 37

# %%
# fetch the rows 11, 24, 37 using iloc and passing the required indexes in an array for berlin weather dataframe
df1.loc[[11,24,37]]
# Out:
#               STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 11  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310114    15 -9999 -9999     0
# 24  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310129    56 -9999 -9999    11
# 37  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310212   930 -9999 -9999    61
#
#     TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 11   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 24   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 37 -9999 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#     WT18  WT03
# 11 -9999 -9999
# 24 -9999 -9999
# 37 -9999 -9999
#
# [3 rows x 21 columns]

# %% [markdown]
# # 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
#to subset rows excluding 5,12,23,56 rows using drop function and using axis=0 to mention to exclude rows and printing first 60 rows to show the exclusion
df1.drop([5,12,23,56],axis=0).head(60)
# Out:
#               STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
# 6   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310108    13 -9999 -9999    11
# 7   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310109    10 -9999 -9999   -22
# 8   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310110 -9999 -9999 -9999     0
# 9   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310112 -9999 -9999 -9999    22
# 10  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310113    13 -9999 -9999     0
# 11  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310114    15 -9999 -9999     0
# ...

# %% [markdown]
# # Project Part2

# %%
#Load datasets from CSV from given location
#users dataframe
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
#sessions dataframe
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
#products dataframe
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
#transactions dataframe
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
#printing top 5 rows of users dataframe
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
#printing top 5 rows of sessions dataframe
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
#printing top 5 rows of product dataframe
products.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
#printing top 5 rows of transactions dataframe
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# # 12. Join users to transactions, keeping all rows from transactions and only matching
# rows from users (left join)

# %%
#joining transactions with users using merge function, how='left' for left join and joinin on UserID field
transactions.merge(users,how='left',on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender Registered  Cancelled
# 0     NaN        NaT        NaT
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3    male 2012-12-21        NaT
# ...

# %% [markdown]
# # 13. Which transactions have a UserID not in users?

# %%
#getting all transaction records execpt those records where UserID is present in transactions but not in users dataframe
#first fetch all UserID values from users and then fetch all those transactions which are having UserIds from users dataframe
#nagate the list to get only those transactions with UserIDs those are not in transactions
#use loc operation to print all transactions
transactions.loc[~transactions['UserID'].isin(users.UserID.values)]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %%
#fetching all transaction Unique UserIds for verification
transactionUserIds = transactions.UserID.unique().tolist()
#fetching all unique UserIDs for verification
usersUserIds = users.UserID.unique().tolist()
set(transactionUserIds)-set(usersUserIds)
#result is matching with above userIds 7, NaN , 7
# Out:
# {nan, 7.0}

# %% [markdown]
# # 14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

# %%
#using inner join merging transactions and users dataframe on UserId field to fetch only matching rows with UserId
transactions.merge(users, on='UserID',how='inner')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# # 15.Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

# %%
#merging transactions and users dataframe using full outer join to show all records with /with out matching userId field in both dataframes
transactions.merge(users,on='UserID',how='outer')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaT     4.0        NaN       NaN   Brielle
# 11            NaN             NaT     5.0        NaN       NaN  Benjamin
#
# ...

# %%
users['Registered'] = pd.to_datetime(users.Registered)
users['Cancelled'] = pd.to_datetime(users.Cancelled)
transactions['TransactionDate'] = pd.to_datetime(transactions.TransactionDate)
sessions['SessionDate'] = pd.to_datetime(sessions.SessionDate)

# %% [markdown]
# # 16. Determine which sessions occurred on the same day each user registered

# %%
#merge sessions dataframe with users dataframe using equi join (inner join) from sessions using SessionDate and UserId and on Users using Registered and UserId
sessions.merge(users,how='inner',left_on=['SessionDate','UserID'],right_on=['Registered','UserID'])
# Out:
#    SessionID SessionDate  UserID     User  Gender Registered  Cancelled
# 0          2  2010-08-01       2    Pedro    male 2010-08-01 2010-08-08
# 1          9  2013-07-17       4  Brielle  female 2013-07-17        NaT

# %% [markdown]
# # 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
# users.shape[0] will give total number of rows in users and same in products.shape[0]
#np.repeat will generage an array from 1 to number of rows in each dataframe
# after creating two dataframes by appending key values with row numbers
# do merge of both dataframes based on key value and it will result cartesian of UserId and ProductId dataframe
df1 = pd.DataFrame({'key':np.repeat(1,users.shape[0]),'UserID':users.UserID})
df2 = pd.DataFrame({'key':np.repeat(1,products.shape[0]),'ProductID':products.ProductID})
user_products = pd.merge(df1,df2,on='key')[['UserID','ProductID']]
user_products
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# # 18. Determine how much quantity of each product was purchased by each user

# %%
#first group by transactions based on UserID and ProductID, then select quantity and do by sum() operation
##In the class it was asked to show Product Name instead of Product Id to work on merging two tables 

#transactions.merge(products,on='ProductID',how='inner').groupby(['UserID','Product'])['Quantity'].sum()
#transactions.groupby(['UserID','ProductID'])['Quantity'].sum()

# %%
#determine how much quantity of each product was purchased by user
pd.merge(user_products,transactions,how='left',on=['UserID','ProductID']).groupby(['UserID','ProductID']).apply(lambda x:pd.Series(dict(quantity=x.Quantity.sum()))).reset_index().fillna(0)
# Out:
#     UserID  ProductID  quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %% [markdown]
# # 19. For each user, get each possible pair of pair transactions (TransactionID1,TransacationID2)

# %%
#Do a self join on transactions based on user ids and it gives a cartesian on transactions with each user
pd.merge(transactions,transactions,on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %% [markdown]
# # 20. Join each user to his/her first occuring transaction in the transactions table

# %%
#first sort the transactions by Transactions and then group by UserId and fetch first records and then reset the index
transactions.sort_values('TransactionDate').groupby(['UserID']).first().reset_index()
# Out:
#    UserID  TransactionID TransactionDate  ProductID  Quantity
# 0     1.0              4      2012-08-26          2         3
# 1     2.0              5      2013-06-06          4         1
# 2     3.0              2      2011-05-26          4         1
# 3     7.0              1      2010-08-21          2         1

# %%
#printing this to test the results are correct or not
transactions.sort_values('UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 6              7      2013-12-30     3.0          4         1
# 9             10      2016-05-08     3.0          4         4
# 0              1      2010-08-21     7.0          2         1
# 8              9      2015-04-24     7.0          4         3
# 7              8      2014-04-24     NaN          2         3

# %% [markdown]
# # 21. Test to see if we can drop columns

# %%
#copying users dataframe to UsersTestDrop dataframe in order to keep the master users dataframe intact
UsersTestDrop = users.copy()
#dropping Registered column from UsersTestDrop dataframe 
UsersTestDrop.drop(['Registered'], axis=1,inplace=True)
#printing users dataframe
print(users,'\n')
print('Users Dataframe after deleting the Registered Column')
#printing 
print(UsersTestDrop)
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN
#
#    UserID      User  Gender   Cancelled
# 0       1   Charles    male         NaN
# 1       2     Pedro    male  2010-08-08
# 2       3  Caroline  female  2016-06-07
# 3       4   Brielle  female         NaN
# 4       5  Benjamin    male         NaN

# %% [markdown]
# # 22. Demonistration of any preprocessing step that is not given here

# %%
#Fill na  with -1
#Fill NaN or any other missing values with -1 , a preprocessing step that is not given here in the project
newtransactions = transactions.fillna(-1)
#Observe that transaction with id 8 has NaN earlier but now having -1
print(transactions.iloc[7])
print('\n')
print("before fill na :",transactions.iloc[7].UserID)
print("after fill na filling with -1 :",newtransactions.iloc[7].UserID)
print('\n')
print(newtransactions.iloc[7])
# Out:
# TransactionID               8
# TransactionDate    2014-04-24
# UserID                    NaN
# ProductID                   2
# Quantity                    3
# Name: 7, dtype: object
#
#
# before fill na : nan
# after fill na filling with -1 : -1.0
#
#
# TransactionID               8
# TransactionDate    2014-04-24
# UserID                     -1
# ProductID                   2
# Quantity                    3
# Name: 7, dtype: object

# %%
#drop records which are not having date field in cancelled row
newUsers = users.copy()
print(users)
newUsers.dropna()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN
#    UserID      User  Gender  Registered   Cancelled
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07

# %%
#forward fill the values where ever NaN is there
newUsers2 = users.copy()
print(users)
newUsers2.fillna(method='ffill')
#note that first values is already NaN , thats why it is not modified
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17  2016-06-07
# 4       5  Benjamin    male  2010-11-25  2016-06-07
